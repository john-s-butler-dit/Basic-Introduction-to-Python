# %% [markdown]
# <a href="https://colab.research.google.com/github/john-s-butler-dit/Basic-Introduction-to-Python/blob/master/W2T4%20FrequenciesSolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Frequency, Week 2 Tutorial 4

# %% [markdown]
# In this notebook we will plot oscillations using sinewaves.

# %% [markdown]
# ### Libraries

# %%
# LIBRARY
import numpy as np # vector manipulation

# THIS IS FOR PLOTTING
# %matplotlib inline
import matplotlib.pyplot as plt # side-stepping mpl backend
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Sinewave
# A sine wave describes a periodic signal of amplitude, $A$ and frequency $f$ Hz, over a time period $t$:
# $$ A\sin(2\pi \ f \  t). $$
# The plot below shows a sinewave of amplitude 3 and a frequency of 7 Hz from 0 to 10 in steps of 0.01:
# $$ 3\sin(2\pi \ 7 \  t). $$

# %%
time=np.arange(0,10,0.01)
Amplitude=3
freq=7

Sinewave=Amplitude*np.sin(2*np.pi*freq*time)


fig = plt.figure(figsize=(8,4)) # This setups the size of the figure
plt.plot(time,Sinewave,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.show() # This plots the figure

# %% [markdown]
# ## Summation of Sinewaves
# Summing sinewaves together results in interesting new signals.
# Here we add together three sinewaves over a period from 0 to 10 with 0.001 steps:
# 1. Amplitude 3 with a frequency of 0.5 Hz;
# 2. Amplitude 1 with a frequency of 2 Hz;
# 3. Amplitude 0.1 with a frequency of 9 Hz.
#
#
# The plot below shows the first sinewave:
# $$ 3 \sin(2  \pi 0.5 t), $$
# from 0 to 10.

# %%
time=np.arange(0,10,0.001)


Amplitude1=3
freq1=0.5

Sinewave1=Amplitude1*np.sin(2*np.pi*freq1*time)

fig = plt.figure(figsize=(6,4)) # This setups the size of the figure

plt.plot(time,Sinewave1,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.title('Sinewave 1: Amplitude 3 with a frequency of 0.5 Hz ')
plt.show()

# %% [markdown]
# The plot below shows the second sinewave:
# $$ 1 \sin(2 \pi 2 t), $$
# from 0 to 10.

# %%
Amplitude2=1
freq2=2
Sinewave2=Amplitude2*np.sin(2*np.pi*freq2*time)

fig = plt.figure(figsize=(6,4)) # This setups the size of the figure

plt.plot(time,Sinewave2,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude ')
plt.title('Sinewave 2: Amplitude 1 with a frequency of 2 Hz')
plt.show()

# %% [markdown]
# The plot below shows the third sinewave:
# $$ 0.1 \sin(2 \pi 9 t), $$
# from 0 to 10.

# %%
Amplitude3=0.1
freq3=9
Sinewave3=Amplitude3*np.sin(2*np.pi*freq3*time)

fig = plt.figure(figsize=(6,4)) # This setups the size of the figure

plt.plot(time,Sinewave3,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude ')
plt.title('Sinewave 3: Amplitude 0.1 with a frequency of 9 Hz')
plt.show()

# %% [markdown]
# The plot below shows each individual sinewave and the summation of them in a grid.

# %%
Sum_Sinewave=Sinewave1+Sinewave2+Sinewave3

fig = plt.figure(figsize=(12,8)) # This setups the size of the figure
plt.subplot(221)
plt.plot(time,Sinewave1,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.ylim([-4,4])
plt.title('Sinewave 1')


plt.subplot(222)
plt.plot(time,Sinewave2,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.ylim([-4,4])
plt.title('Sinewave 2')


plt.subplot(223)
plt.plot(time,Sinewave3,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.ylim([-4,4])
plt.title('Sinewave 3')

plt.subplot(224)
plt.plot(time,Sum_Sinewave,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.ylim([-4,4])
plt.title('Sum of Sinewaves')

plt.tight_layout()
plt.show() # This plots the figure

# %% [markdown]
# ## Problem 1
# Plot a summation of two sine Waves  from 0 to 10:
# 1. the first has an amplitude of 7 with frequency 0.3 Hz;
# 2. the second has an amplitude of 0.4 with a frequency of 5Hz.

# %%
time=np.arange(0,10,0.001)


##############################################################################
## INSERT: Plot a summation of two sinewaves:
## the first an amplitude of 4 with frequency 0.8 Hz;
## the second with an amplitude of 1 with a frequency of 3Hz.
##############################################################################
fig = plt.figure(figsize=(6,4)) # This setups the size of the figure



#######################ANSWER#################################

# SINEWAVE 1
Amplitude1=7
freq1=0.3

Sinewave1=Amplitude1*np.sin(2*np.pi*freq1*time)

# SINEWAVE 2
Amplitude2=0.4
freq2=5
Sinewave2=Amplitude2*np.sin(2*np.pi*freq2*time)

# SUM 
# UNCOMMENT
Sum_Sinewave=Sinewave1+Sinewave2

#######################ANSWER#################################

plt.plot(time,Sum_Sinewave,'-',color='black')


plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.title('Sum of Sine Waves')

plt.tight_layout()
plt.show() # This plots the figure

# %% [markdown]
# ## Problem 2
# Plot a summation of two cosine waves from 0 to 10:
# 1. the first an amplitude of 4 with frequency 0.8 Hz;
# 2. the second with an amplitude of 1 with a frequency of 3Hz.

# %%
time=np.arange(0,10,0.001)


##############################################################################
## INSERT: Plot a summation of two cosinewaves:
## the first an amplitude of 4 with frequency 0.8 Hz;
## the second with an amplitude of 1 with a frequency of 3Hz.
##############################################################################
fig = plt.figure(figsize=(6,4)) # This setups the size of the figure

Amplitude1=4
freq1=0.8

Cosinewave1=Amplitude1*np.cos(np.pi*freq1*time)

Amplitude2=1
freq2=3

Cosinewave2=Amplitude2*np.cos(np.pi*freq2*time)


Sum_Cosinewave=Cosinewave1+Cosinewave2

#######################ANSWER#################################



#######################ANSWER#################################

plt.plot(time,Sum_Cosinewave,'-',color='black')


plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.title('Sum of Cosine Waves')

plt.tight_layout()
plt.show() # This plots the figure

# %% [markdown]
# ---
# # Summary
#
# In this tutorial, we learned:
#
# * To plot and maniplute sine and cosine waves.
