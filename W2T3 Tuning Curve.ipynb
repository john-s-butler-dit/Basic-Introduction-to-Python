# %% [markdown]
# # Tuning Curve, Week 2 Tutorial 3

# %% [markdown]
# In this notebook we will illustrate simple spike analysis for repeated Trials.

# %% [markdown]
# ### Libraries

# %%
# LIBRARY

import numpy as np # vector manipulation
from scipy.stats import norm # Psychometric Function
from scipy.stats import poisson

# THIS IS FOR PLOTTING
# %matplotlib inline
import matplotlib.pyplot as plt # side-stepping mpl backend
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Gaussian Tunning Function
#
# To simulate a single 1000ms trial we generate a matrix of 1000 time 100 trials random numbers between 0 and 1.

# %%
Orientation=np.arange(-40,40,1)
Max_Firing=60
Preferred_Direction=0
tunning_curve= Max_Firing*norm.pdf(Orientation,Preferred_Direction,10)/max(norm.pdf(Orientation,Preferred_Direction,10))
fig = plt.figure(figsize=(8,4)) # This setups the size of the figure
plt.plot(Orientation,tunning_curve,'-',color='black')
plt.xlabel('Orientation')
plt.ylabel('Firing Rate (Hz)')
plt.show() # This plots the figure

# %% [markdown]
# ## Sigmoid Tunning Function
# A neuron will only fire if the probability is below the threshold.
# We set the neuron to have 0 spikes at all 1000 time points and 100 trials.

# %%
Disparity=np.arange(-1,1,0.01)

tunning_curve= 40*norm.cdf(Disparity,0,0.2)



fig = plt.figure(figsize=(8,4)) # This setups the size of the figure
plt.plot(Disparity,tunning_curve,'-',color='black')
plt.xlabel('Disparity')
plt.ylabel('Firing Rate (Hz)')
plt.show() # This plots the figure

# %% [markdown]
# ## Problem 1
# Plot a gaussian tuning for oriention with a max firing rate of 50Hz at 10 degrees and a baseline firing rate of 10Hz with a standard deviation of 5 degrees.

# %%
Orientation=np.arange(-40,40,1)
##############################################################################
## INSERT: Plot a gaussian tuning for oriention with a max firing rate of 50Hz at 10 degrees and a baseline firing rate of 10Hz with a standard deviation of 5 degrees.


##############################################################################
#######################ANSWER#################################



#######################ANSWER#################################

fig = plt.figure(figsize=(8,4)) # This setups the size of the figure
plt.plot(Orientation,tunning_curve,'-',color='black')
plt.xlabel('Orientation')
plt.ylabel('Firing Rate (Hz)')
plt.show() # This plots the figure
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-16868620a1f3> in <module>
#      12
#      13 fig = plt.figure(figsize=(8,4)) # This setups the size of the figure
# ---> 14 plt.plot(Orientation,tunning_curve,'-',color='black')
#      15 plt.xlabel('Orientation')
#      16 plt.ylabel('Firing Rate (Hz)')
#
# ~/.conda/envs/DecisionMaking/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/.conda/envs/DecisionMaking/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/.conda/envs/DecisionMaking/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/.conda/envs/DecisionMaking/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (80,) and (200,)

# %% [markdown]
# ---
# # Summary
#
# In this tutorial, we learned:
#
# * To plot and manipulate a neruonal Tuning function.
