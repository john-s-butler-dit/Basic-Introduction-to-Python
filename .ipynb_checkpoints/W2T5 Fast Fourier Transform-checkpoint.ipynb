# %% [markdown]
# # Frequncy, Week 2 Tutorial 4

# %% [markdown]
# In this notebook we will plot oscillations using sine and consines.

# %% [markdown]
# ### Libraries

# %%
# LIBRARY
import numpy as np # vector manipulation

# THIS IS FOR PLOTTING
# %matplotlib inline
import matplotlib.pyplot as plt # side-stepping mpl backend
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Sinewave
#
# $$ A\sin(\pi \ f \  t), $$

# %%
time=np.arange(0,10,0.01)
Amplitude=3
freq=2

Sinewave=Amplitude*np.sin(np.pi*freq*time)
fig = plt.figure(figsize=(8,4)) # This setups the size of the figure
plt.plot(time,Sinewave,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.show() # This plots the figure

# %% [markdown]
# ## Summation of Sinewaves

# %%
time=np.arange(0,10,0.001)


Amplitude1=3
freq1=0.5

Sinewave1=Amplitude1*np.sin(np.pi*freq1*time)

fig = plt.figure(figsize=(6,4)) # This setups the size of the figure

plt.plot(time,Sinewave1,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.title('Sinewave 1')
plt.show()

# %%
Amplitude2=1
freq2=2
Sinewave2=Amplitude2*np.sin(np.pi*freq2*time)

fig = plt.figure(figsize=(6,4)) # This setups the size of the figure

plt.plot(time,Sinewave2,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.title('Sinewave 2')
plt.show()

# %%
Amplitude3=0.1
freq3=10
Sinewave3=Amplitude3*np.sin(np.pi*freq3*time)

fig = plt.figure(figsize=(6,4)) # This setups the size of the figure

plt.plot(time,Sinewave3,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.title('Sinewave 3')
plt.show()

# %%
Sum_Sinewave=Sinewave1+Sinewave2+Sinewave3

fig = plt.figure(figsize=(12,8)) # This setups the size of the figure
plt.subplot(221)
plt.plot(time,Sinewave1,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.ylim([-4,4])
plt.title('Sinewave 1')


plt.subplot(222)
plt.plot(time,Sinewave2,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.ylim([-4,4])
plt.title('Sinewave 2')


plt.subplot(223)
plt.plot(time,Sinewave3,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.ylim([-4,4])
plt.title('Sinewave 3')

plt.subplot(224)
plt.plot(time,Sum_Sinewave,'-',color='black')
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.ylim([-4,4])
plt.title('Sum of Sinewaves')

plt.tight_layout()
plt.show() # This plots the figure

# %% [markdown]
# ## Problem 1
# Plot a summation of two sinewaves:
# 1. the first an amplitude of 4 with frequency 0.8 Hz;
# 2. the second with an amplitude of 1 with a frequency of 3Hz.

# %%
time=np.arange(0,10,0.001)


##############################################################################
## INSERT: Plot a summation of two sinewaves:
## the first an amplitude of 4 with frequency 0.8 Hz;
## the second with an amplitude of 1 with a frequency of 3Hz.
##############################################################################
fig = plt.figure(figsize=(6,4)) # This setups the size of the figure


plt.plot(time,Sum_Sinewave,'-',color='black')

#######################ANSWER#################################



#######################ANSWER#################################


plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.title('Sum of Sinewaves')

plt.tight_layout()
plt.show() # This plots the figure

# %% [markdown]
# ---
# # Summary
#
# In this tutorial, we learned:
#
# * To plot and manipulate a neruonal Tuning function.
